# %%
import pandas as pd
import requests

# %%
# Response 200 means all OK
# 404 Not Available
# 500 Server Error

# %%
resp = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=5b75cf856f001d914c9859aea5cfba02&language=en-US&page=1")
print(resp.json())

# temp_df = pd.DataFrame(resp.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
# print(temp_df)
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 37.061, 'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.708, 'vote_count': 27762}, {'adult': False, 'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg', 'genre_ids': [18, 80], 'id': 238, 'original_language': 'en', 'original_title': 'The Godfather', 'overview': 'Spanning 
# ...

# %%
df = pd.DataFrame()
for i in range(1, 429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=5b75cf856f001d914c9859aea5cfba02&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
    df = df._append(temp_df, ignore_index=True)

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')

# %%
import requests

url = "https://myanimelist.p.rapidapi.com/v2/manga/genres"

headers = {
	"x-rapidapi-key": "c5c9149262msh69b56666c0a0210p17d947jsnb66b90169abb",
	"x-rapidapi-host": "myanimelist.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# [{'title': 'Action', 'amount': 10216, 'id': 1}, {'title': 'Adventure', 'amount': 4423, 'id': 2}, {'title': 'Avant Garde', 'amount': 88, 'id': 5}, {'title': 'Award Winning', 'amount': 505, 'id': 46}, {'title': 'Boys Love', 'amount': 10957, 'id': 28}, {'title': 'Comedy', 'amount': 15609, 'id': 4}, {'title': 'Drama', 'amount': 10598, 'id': 8}, {'title': 'Fantasy', 'amount': 13510, 'id': 10}, {'title': 'Girls Love', 'amount': 1916, 'id': 26}, {'title': 'Gourmet', 'amount': 565, 'id': 47}, {'title': 'Horror', 'amount': 1901, 'id': 14}, {'title': 'Mystery', 'amount': 2658, 'id': 7}, {'title': 'Romance', 'amount': 19015, 'id': 22}, {'title': 'Sci-Fi', 'amount': 3513, 'id': 24}, {'title': 'Slice of Life', 'amount': 5356, 'id': 36}, {'title': 'Sports', 'amount': 1244, 'id': 30}, {'title': 'Supernatural', 'amount': 8215, 'id': 37}, {'title': 'Suspense', 'amount': 770, 'id': 45}, {'title': 'Ecchi', 'amount': 3868, 'id': 9}, {'title': 'Erotica', 'amount': 10233, 'id': 49}, {'title': 'Hentai', 'a
# ...

# %%
for i in response.json():
    print(i)
# Out:
# {'title': 'Action', 'amount': 10216, 'id': 1}
# {'title': 'Adventure', 'amount': 4423, 'id': 2}
# {'title': 'Avant Garde', 'amount': 88, 'id': 5}
# {'title': 'Award Winning', 'amount': 505, 'id': 46}
# {'title': 'Boys Love', 'amount': 10957, 'id': 28}
# {'title': 'Comedy', 'amount': 15609, 'id': 4}
# {'title': 'Drama', 'amount': 10598, 'id': 8}
# {'title': 'Fantasy', 'amount': 13510, 'id': 10}
# {'title': 'Girls Love', 'amount': 1916, 'id': 26}
# {'title': 'Gourmet', 'amount': 565, 'id': 47}
# {'title': 'Horror', 'amount': 1901, 'id': 14}
# {'title': 'Mystery', 'amount': 2658, 'id': 7}
# {'title': 'Romance', 'amount': 19015, 'id': 22}
# {'title': 'Sci-Fi', 'amount': 3513, 'id': 24}
# {'title': 'Slice of Life', 'amount': 5356, 'id': 36}
# {'title': 'Sports', 'amount': 1244, 'id': 30}
# {'title': 'Supernatural', 'amount': 8215, 'id': 37}
# {'title': 'Suspense', 'amount': 770, 'id': 45}
# {'title': 'Ecchi', 'amount': 3868, 'id': 9}
# {'title': 'Erotica', 'amount': 10233, 'id': 49}
# ...

# %%
url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"developer jobs in chicago","page":"1","num_pages":"1","country":"us","date_posted":"all"}

headers = {
	"x-rapidapi-key": "c5c9149262msh69b56666c0a0210p17d947jsnb66b90169abb",
	"x-rapidapi-host": "jsearch.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': '9a6326c3-73a4-4eb5-ada6-7ced17b2d265', 'parameters': {'query': 'developer jobs in chicago', 'page': 1, 'num_pages': 1, 'date_posted': 'all', 'country': 'us', 'language': 'en'}, 'data': [{'job_id': 'Cy0aEPqubiPPabQSAAAAAA==', 'job_title': 'Developer Support Associate - New Graduate, Spring 2025', 'employer_name': 'Okta', 'employer_logo': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTYJSvURr9-5etdinV0yXzo-u5EYP5qQIuPWNWh&s=0', 'employer_website': 'http://www.okta.com/', 'job_publisher': 'LinkedIn', 'job_employment_type': 'Full-time', 'job_employment_types': ['FULLTIME'], 'job_apply_link': 'https://www.linkedin.com/jobs/view/developer-support-associate-new-graduate-spring-2025-at-okta-4162728630?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'job_apply_is_direct': False, 'apply_options': [{'publisher': 'LinkedIn', 'apply_link': 'https://www.linkedin.com/jobs/view/developer-support-associate-new-graduate-spring-2
# ...

# %%
response.json()['data']
# Out:
# [{'job_id': 'Cy0aEPqubiPPabQSAAAAAA==',
#   'job_title': 'Developer Support Associate - New Graduate, Spring 2025',
#   'employer_name': 'Okta',
#   'employer_logo': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTYJSvURr9-5etdinV0yXzo-u5EYP5qQIuPWNWh&s=0',
#   'employer_website': 'http://www.okta.com/',
#   'job_publisher': 'LinkedIn',
#   'job_employment_type': 'Full-time',
#   'job_employment_types': ['FULLTIME'],
#   'job_apply_link': 'https://www.linkedin.com/jobs/view/developer-support-associate-new-graduate-spring-2025-at-okta-4162728630?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic',
#   'job_apply_is_direct': False,
#   'apply_options': [{'publisher': 'LinkedIn',
#     'apply_link': 'https://www.linkedin.com/jobs/view/developer-support-associate-new-graduate-spring-2025-at-okta-4162728630?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic',
#     'is_direct': False},
# ...

# %% [markdown]
# job_id, job_title, employer_name, employer_logo, employer_website, job_publisher, job_employment_type, job_apply_link, apply_options

# %%
df = pd.DataFrame(response.json()['data'])
